# %%
import edautils
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/data-breast-cancer.csv')

# %%
edautils.plot_numerical(df)
# Out:
# (<Figure size 1080x1440 with 30 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xb2a0290b8>)

# %%
edautils.plot_categorical(df)
# Out:
# (<Figure size 1440x1080 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0xb2b991320>)
